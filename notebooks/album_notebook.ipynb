# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
pd.options.display.max_rows = 10000
pd.options.display.max_seq_items = 10000

# %%
album_df = pd.read_csv(r'../data/album_df.csv', index_col=[0])
columns = pd.read_csv(r'../data/column.csv', index_col=[0])

# %%
columns.columns
# Out:
# Index(['Alternative Rock', 'Art Rock', 'Progressive Rock', 'Conscious Hip Hop',
#        'West Coast Hip Hop', 'Jazz Rap', 'Experimental Rock', 'Electronic',
#        'Shoegaze', 'Noise Pop', 'Pop Rock', 'Abstract Hip Hop', 'Glam Rock',
#        'Psychedelic Pop', 'New Wave', 'Post-Punk', 'Avant-Garde Jazz',
#        'Third Stream', 'Spiritual Jazz', 'Dream Pop', 'Neo-Psychedelia',
#        'Heavy Metal', 'Hard Rock', 'Modal Jazz', 'Cool Jazz',
#        'East Coast Hip Hop', 'Boom Bap', 'Hardcore Hip Hop', 'Post-Rock',
#        'Baroque Pop', 'Indie Folk', 'Indie Rock', 'Pop Rap', 'Hip Hop',
#        'Post-Hardcore', 'Math Rock', 'Contemporary Folk', 'Singer/Songwriter',
#        'Gothic Rock', 'Rock', 'Jangle Pop', 'Indie Pop', 'Folk Rock',
#        'Jazz Fusion', 'Progressive Pop', 'Ambient', 'Trip Hop', 'Art Pop',
#        'Art Punk', 'Instrumental Hip Hop', 'Experimental Hip Hop',
#        'Plunderphonics', 'Symphonic Prog', 'Psychedelic Rock',
#        'Psychedelic Folk', 'Lo-Fi / Slacker Rock', 'Blues Rock', 'Acid Rock',
#        'Soul', 'Industrial Hip Hop', 'Chamber Pop', 'Chipmunk Soul',
#        'Alternative RB', 'Neo-Soul', 'Experimental', 'Thrash Metal',
#        'Noise Rock', 'Acoustic Rock', 'Krautrock', 'Southern Hip Hop',
#        'Ambient Techno', 'IDM', 'Country Rock', 'Proto-Punk', 'Garage Rock',
#        'Punk Rock', 'Heartland Rock', 'Jam Band', 'Film Soundtrack',
#        'Synth Funk', 'Grunge', 'Jazz-Rock', 'Country', 'NWOBHM',
#        'Industrial Rock', 'Technical Death Metal', 'Free Jazz', 'Power Pop',
#        'Post-Bop', 'Television Music', 'Dark Jazz', 'Glitch Pop',
#        'French House', 'Chamber Folk', 'Gangsta Rap', 'Roots Rock', 'MPB',
#        'Progressive Electronic', 'Film Score', 'Space Ambient',
#        'Southern Soul', 'Soft Rock', 'Jazz-Funk', 'Garage Rock Revival',
#        'Funk', 'Spaghetti Western', 'Minimalism', 'Dance-Punk', 'Indietronica',
#        'Chicago Soul', 'Pop Punk', 'Synthpop', 'Post-Punk Revival',
#        'Progressive Folk', 'Downtempo', 'Hard Bop', 'ECM Style Jazz',
#        'Rap Metal', 'Alternative Metal', 'Progressive Metal',
#        'Contemporary RB', 'Funk Rock', 'Zeuhl', 'Swamp Rock', 'Twee Pop',
#        'Future Garage', 'Dubstep', 'Video Game Music', 'Baggy / Madchester',
#        'Metalcore', 'Christmas Music', 'Samba', 'Southern Rock', 'Orchestral',
#        'Modern Classical', 'Stoner Rock', 'Horror Punk', 'Freak Folk',
#        'Hardcore Punk', 'Stoner Metal', 'Doom Metal', 'Afrobeat', 'Pop',
#        'Dance-Pop', 'Symphony', 'Romanticism', 'Ethereal Wave', 'Mathcore',
#        'Harsh Noise', 'Avant-Folk', 'Death Metal', '16-bit', 'Samba-rock',
#        'Jazz', 'Drone Metal', 'Post-Metal', 'Drone', 'Alt-Country',
#        'UK Hip Hop', 'American Primitivism', 'Power Metal', 'US Power Metal',
#        'New Age', 'Cinematic Classical', 'Sequencer  Tracker', 'Opera',
#        'Folk Pop', 'Roots Reggae', 'Heavy Psych', 'Ambient Pop', 'Deep Soul',
#        'Rock Opera', 'Experimental Big Band', 'Slowcore', 'Shibuya-kei',
#        'Picopop', 'Atmospheric Black Metal', 'Political Hip Hop', 'Acid Jazz',
#        'Lounge', 'Vocal Jazz', 'Rhythm  Blues', 'Bossa nova', 'Samba-jazz',
#        'Samba Soul', 'Post-Industrial', 'Modern Creative',
#        'Space Rock Revival', 'No Wave', 'Totalism', 'Electropop',
#        'Brutal Death Metal', 'Piano Rock', 'Britpop', 'Classical Period',
#        'Avant-Garde Metal', 'Bebop', 'Psychedelic Soul', 'Stand-Up Comedy',
#        'Melodic Black Metal', 'Canterbury Scene', 'Smooth Soul',
#        'Sophisti-Pop', 'Tribal Ambient', 'Symphonic Black Metal',
#        'Black Metal', 'Baroque Music', 'Oratorio',
#        'Christian Liturgical Music', 'Memphis Rap', 'Space Rock',
#        'Atmospheric Sludge Metal', 'Son cubano', 'Bolero', 'Cuban Music',
#        'P-Funk', 'Horrorcore', 'Spoken Word', 'Standards', 'Pagan Black Metal',
#        'Choral', 'Progressive Country', 'Big Band', 'Rock  Roll',
#        'Chicago Blues', 'Dark Folk', 'Sludge Metal', 'Free Folk',
#        'Ritual Ambient', 'Latin Rock', 'Caribbean Folk Music', 'Dirty South',
#        'Neoclassical Darkwave', 'Glitch Hop', 'Wonky', 'Salsa dura',
#        'Folktronica', 'Americana', 'Midwest Emo', 'Folk Metal',
#        'Cartoon Music', 'Tuvan Throat Singing', 'Bulgarian Folk Music',
#        'White Voice', 'Tango nuevo', 'Electronic Dance Music', 'G-Funk',
#        'Folk Punk', 'Soul Jazz', 'Emo', 'Chamber Music', 'House',
#        'Electroacoustic', 'Epic Doom Metal', 'Traditional Doom Metal',
#        'J-Rock', 'Manguebeat', 'Cloud Rap', 'Disco', 'Samba-choro',
#        'Neoclassical New Age', 'Impressionism', 'Mod', 'Boogie Rock', 'Trap',
#        'Rock in Opposition', 'Free Improvisation', 'Avant-Prog', 'Tropicália',
#        'Concerto', 'Big Beat', 'Ragtime', 'American Folk Music', 'French Pop',
#        'Gothic Country', 'Show Tunes', 'Western Classical Music',
#        'Expressionism', 'Serialism', 'Breakbeat', 'Acid House',
#        'British Folk Rock', 'K-Pop', 'Future Bass', 'Industrial Metal',
#        'Holiday Music', 'Techno', 'Flamenco Jazz', 'Punk Blues', 'Satire',
#        'Electric Blues', 'Post-Minimalism', 'Progressive Big Band',
#        'Alternative Dance', 'Jazz Pop', 'Berlin School', 'Industrial',
#        'Mande Music', 'Canzone d'autore', 'Technical Thrash Metal',
#        'Microtonal Classical', 'Synth Punk', 'Minimal Synth', 'Space Age Pop',
#        'Emoviolence', 'Hindustani Classical Music', 'Andalusian Rock',
#        'Acousmatic', 'Surf Music', 'Bubblegum Bass', 'Deconstructed Club',
#        'Grindcore', 'Soul Blues', 'Blues', 'Viking Metal',
#        'Melodic Death Metal', 'Celtic Rock', 'Celtic Punk', 'Baião',
#        'Pub Rock', 'Ambient Trance', 'Progressive Trance',
#        'Progressive Breaks', 'Screamo', 'Sound Collage', 'Deep House',
#        'Dark Ambient', 'Poezja śpiewana', 'European Free Jazz', 'Sunshine Pop',
#        'Acoustic Blues', 'Dark Cabaret', 'Death Doom Metal', 'Chamber Jazz',
#        'City Pop', 'Nu Metal', 'Cowpunk', 'Tone Poem',
#        'Nueva canción latinoamericana', 'Lieder', 'Gothic Metal', 'Coldwave',
#        'Ska Punk', 'Skate Punk', 'Neo-Prog', 'Piano Blues', 'Vaporwave',
#        'Symphonic Metal', 'Symphonic Rock', 'Jazz manouche',
#        'Renaissance Music', 'Neofolk', 'Afoxé', 'Depressive Black Metal',
#        'Tape Music', 'Stochastic Music', 'Girl Group', 'Brill Building',
#        'Country Soul', 'Rock urbano español', 'Death Industrial', 'Cowboy',
#        'Blackgaze', 'Microhouse', 'Vanguarda paulista', 'Deathgrind',
#        'Andean Rock', 'Electric Texas Blues', 'Flamenco', 'Garage Punk',
#        'Pop Soul', 'Christian Rock', 'Funeral Doom Metal', 'Funk Metal',
#        'Comedy', 'Psychobilly', 'Soukous', 'Fon Music', 'Chanson à texte',
#        'Easy Listening', 'Nueva trova', 'Chopped and Screwed', 'FM Synthesis',
#        'Mod Revival', 'Bluegrass', 'Traditional Country', 'Klezmer', 'Gospel',
#        'Spirituals', 'Alt-Pop', 'Breakcore', 'Drill and Bass',
#        'Flamenco nuevo', 'Nu-Disco', 'Outlaw Country', 'Swing',
#        'Hill Country Blues', 'Zolo', 'Nueva canción española', 'Mashup',
#        'New Orleans RB', 'Poetry', 'French Hip Hop', 'Gregorian Chant',
#        'Ethio-Jazz', 'Afro-Jazz', 'Spectralism', 'Jewish Music', 'Chanson',
#        'Powerviolence', 'Noise', 'Acid Techno', 'Progressive House',
#        'Merseybeat', 'Progressive Bluegrass', 'UK Bass', 'Jingles',
#        'Polyphonic Chant', 'Freakbeat', 'Spanish Classical Music',
#        'Neoclassicism', 'Synthwave', 'Bedroom Pop', 'Musical Comedy',
#        'Musical Parody', 'Novelty', 'J-Pop', 'Música de intervenção',
#        'Groove Metal', 'Turntable Music', 'Latin Alternative', 'D-Beat',
#        'Indeterminacy', 'Minimal Wave', 'Blue-Eyed Soul', 'Danzón',
#        'Afro-Cuban Jazz', 'Speed Metal', '2 Tone', 'New Jack Swing',
#        'Raga Rock', 'New Romantic', 'Neue Deutsche Härte', 'Samba-canção',
#        'Psychedelia', 'Portuguese Music', 'Speed Garage', 'UK Garage',
#        'Chiptune', 'Crust Punk', 'Motown Sound', 'Delta Blues',
#        'Mexican Folk Music', 'Ranchera', 'Southern Metal', 'Celtic New Age',
#        'Celtic Folk Music', 'Deutschrock', 'EAI', 'Irish Folk Music',
#        'Traditional Black Gospel', 'Neo-Pagan Folk', 'Nordic Folk Music',
#        'Qawwali', 'Comedy Rock', 'Drumless', 'English Folk Music',
#        'Atmospheric Drum and Bass', 'Nu Jazz', 'Nouvelle chanson française',
#        'Piedmont Blues', 'Country Blues', 'Goregrind', 'Country Pop',
#        'Musique concrète', 'Dixieland', 'Latin Jazz', 'Brazilian Folk Music',
#        'Nova cançó', 'Dub Poetry', 'Reductionism', 'Rockabilly',
#        'Outsider House', 'Emo-Pop', 'Minimal Techno', 'British Blues',
#        'Northern American Music', 'New Age Kirtan', 'Lovers Rock',
#        'Third Wave Ska', 'Cabaret', 'Dreampunk', 'Field Recordings',
#        'Nature Recordings', 'Stride', 'Polish Folk Music', 'Boogie', 'Jungle',
#        'Horror Synth', 'Dub', 'Reggae', 'Deathcore', 'Melodic Metalcore',
#        'Glam Punk', 'Djent', 'Choro', 'Hypnagogic Pop', 'Noisecore',
#        'Afro-Funk', 'New Orleans Blues', 'Onkyo', 'Traditional Pop',
#        'Philly Soul', 'Deep Funk', 'Songhai Music', 'Darkwave', 'Glitch',
#        'Japanese Hardcore', 'Latin Rap', 'Dub Techno', 'Ambient Dub',
#        'Folk Baroque', 'Oi!', 'Illbient', 'Canzone napoletana', 'Deathrock',
#        'Tizita', 'Jamaican Ska', 'Scottish Folk Music', 'Swamp Blues', ' ',
#        'British Brass Band', 'Surf Rock', 'Turntablism', 'Microsound',
#        'A cappella', 'Ska', 'Beat Poetry', 'Talking Blues',
#        'Electro-Industrial', 'Electro House', 'Mexican Music', 'New Rave',
#        'Electro-Disco', 'Electroclash', 'Funky House', 'British Rhythm  Blues',
#        '2-Step', 'Brutal Prog', 'Carols', 'Radio Broadcast Recordings',
#        'Surf Punk', 'Anarcho-Punk', 'Space Disco', 'Tribal House',
#        'Country Gospel', 'New Orleans Brass Band', 'Fanfare',
#        'Sounds and Effects', 'Classical Crossover', 'Epic Music', 'Psybient',
#        'Sea Shanties', 'Chinese Opera', 'Mid-School Hip Hop',
#        'Traditional Folk Music', 'Yacht Rock', 'Dungeon Synth',
#        'Black Ambient', 'Classical Waltz', 'Digital Hardcore', 'Rap Rock',
#        'Conducted Improvisation', 'Exotica', 'Tech House', 'Interview',
#        'Kagura', 'Electro', 'Pop Reggae', 'Smooth Jazz', 'Gamelan', 'Noh',
#        'Shōmyō', 'Gamelan jegog', 'Kecak', 'Guajira', 'Descarga', 'Guaracha',
#        'Music Hall', 'Calypso', 'Japanese Folk Music', 'Doo-Wop',
#        'Cocktail Nation', 'Vocal Surf', 'Honky Tonk', 'Neo-Medieval Folk',
#        'Junkanoo', 'Goombay', 'Rocksteady', 'Candomblé Music', 'Samba de roda',
#        'Nu Skool Breaks', 'Saeta', 'Medieval Classical Music', 'Broken Beat',
#        'Drum and Bass', 'Jazzstep', 'Halloween Music', 'Soundtracks', 'Hymns',
#        'Italian Folk Music', 'Maracatu', 'Coco', 'Samba de terreiro',
#        'Futurism', 'Trova', 'Frevo', 'Funktronica', 'Vaudeville',
#        'Classical March', 'Cakewalk', 'Jazz Poetry', 'Garage House',
#        'Japanese Hip Hop', 'Sonorism', 'Tech Trance', 'Freestyle', 'Bitpop',
#        'Martial Industrial', 'Min'yō', 'Trap Metal', 'Operetta',
#        'French-Canadian Folk Music', 'Appalachian Folk Music', 'Spacesynth',
#        'Indigenous Andean Music', 'Conjunto andino', 'Birdsong', 'Goa Trance',
#        'Central Asian Throat Singing', 'UK Street Soul', 'Southern Gospel',
#        'Musette', 'Persian Classical Music', 'West Asian Folk Music',
#        'Byzantine Music', 'Chillstep', 'Darksynth', 'Sketch Comedy', 'Enka',
#        'Emocore', 'Work Songs', 'Old-Time', 'Cueca', 'Samba-exaltação',
#        'Tejano', 'Celtic Metal', 'Musique concrète instrumentale', 'Ragga',
#        'Radio Drama', 'Lullabies', 'Riot Grrrl', 'Arabic Jazz',
#        'Ukrainian Folk Music', 'Rumba flamenca', 'Highlife', 'Close Harmony',
#        'Snap', 'Polka', 'Scrumpy and Western', 'Bluegrass Gospel', 'Footwork',
#        'Breakbeat Hardcore', 'Zydeco', 'Latin American Classical Music',
#        'European Folk Music', 'Euro House', 'Hispanic American Music',
#        'Swedish Folk Music', 'Power Electronics', 'Japanese Music',
#        'Techno kayō', 'Jongo', 'Ambient Noise Wall', 'Crossover Thrash',
#        'Carnatic Classical Music', 'Trance', 'Mobb Music', 'Ballroom',
#        'Library Music', 'Forró', 'Vaportrap', 'Future Funk',
#        'Melodic Hardcore', 'Barbershop', 'Hispanic American Folk Music',
#        'Sertanejo de raiz', 'Ambient House', 'Animal Sounds', 'Fado',
#        'Cante alentejano', 'British Dance Band', 'UK82', 'Chachachá',
#        'East Asian Folk Music', 'Anatolian Rock', 'Fado de Coimbra',
#        'Vocal Trance', 'Russian Orthodox Liturgical Music', 'Byzantine Chant',
#        'Cyber Metal', 'Deathstep', 'Mariachi', 'Cumbia mexicana',
#        'Son jarocho', 'West African Music', 'Arabic Folk Music',
#        'Rune Singing', 'Arabic Music', 'Beat Music', 'Neoclassical Metal',
#        'Dimotika', 'Greek Folk Music', 'Tibetan Music',
#        'Arabic Classical Music', 'Drill', 'Hyphy', 'Catalan Folk Music',
#        'Hi-NRG', 'War Metal', 'Darkside', 'Latin Funk', 'Neo-Acoustic',
#        'Denpa', 'Chinese Folk Music', 'Utopian Virtual', 'Israeli Folk Music',
#        'Oriental Jewish Music', 'Avtorskaya pesnya', 'Nyahbinghi', 'Darkstep',
#        'Gorenoise', 'Fairy Tales', 'Indigenous Australian Traditional Music',
#        'Salsa', 'Comedy Rap', 'AOR', 'Hungarian Folk Music', 'Boogie Woogie',
#        'Tsugaru shamisen', 'Gagaku', 'Lowercase', 'Vals criollo', 'Tango',
#        'Funk carioca', 'Dancehall', 'Power Noise', 'Thrashcore', 'Glam Metal',
#        'Gypsy Punk', 'Azmari', 'Children's Music', 'melancholic', 'anxious',
#        'futuristic', 'male vocals', 'existential', 'alienation', 'atmospheric',
#        'lonely', 'cold', 'pessimistic', 'progressive', 'concept album',
#        'introspective', 'serious', 'longing', 'bittersweet', 'fantasy', 'epic',
#        'complex', 'philosophical', 'surreal', 'poetic', 'abstract',
#        'political', 'conscious', 'protest', 'urban', 'eclectic', 'passionate',
#        'sombre', 'cryptic', 'noisy', 'ethereal', 'romantic', 'love', 'dense',
#        'hypnotic', 'psychedelic', 'female vocals', 'lush', 'mellow', 'melodic',
#        'warm', 'summer', 'uplifting', 'sentimental', 'sampling', 'playful',
#        'humorous', 'mysterious', 'boastful', 'drugs', 'sexual', 'raw',
#        'avant-garde', 'nihilistic', 'science fiction', 'anthemic',
#        'rock opera', 'energetic', 'triumphant', 'quirky', 'happy', 'rhythmic',
#        'repetitive', 'instrumental', 'suite', 'suspenseful', 'technical',
#        'manic', 'crime', 'violence', 'Christian', 'improvisation', 'spiritual',
#        'acoustic', 'meditative', 'religious', 'heavy', 'war', 'dark',
#        'ominous', 'nocturnal', 'soothing', 'calm', 'apocalyptic',
#        'Wall of Sound', 'death', 'optimistic', 'hedonistic', 'vulgar',
#        'aggressive', 'uncommon time signatures', 'pastoral', 'autumn',
#        'misanthropic', 'satirical', 'sarcastic', 'sad', 'rebellious',
#        'depressive', 'folklore', 'aquatic', 'androgynous vocals', 'nature',
#        'sensual', 'winter', 'breakup', 'lo-fi', 'forest', 'angry', 'chaotic',
#        'sparse', 'history', 'LGBT', 'disturbing', 'funereal', 'dissonant',
#        'apathetic', 'soft', 'occult', 'tropical', 'vocal group', 'polyphonic',
#        'alcohol', 'peaceful', 'self-hatred', 'spring', 'suicide', 'mechanical',
#        'party', 'mashup', 'rain', 'desert', 'martial', 'minimalistic',
#        'medieval', 'satanic', 'anti-religious', 'infernal', 'Christmas',
#        'orchestral', 'paranormal', 'pagan', 'ritualistic', 'symphony',
#        'choral', 'space', 'chamber music', 'mythology', 'tribal', 'jingle',
#        'lethargic', 'scary', 'atonal', 'deadpan', 'monologue', 'sports',
#        'hateful', 'oratorio', 'ensemble', 'opera', 'concerto', 'a cappella',
#        'anarchism', 'ballad', 'educational', 'string quartet', 'mood', '...',
#        'Halloween', 'fairy tale', 'natural', 'seasonal', 'generative music',
#        'microtonal', 'patriotic', 'skit', 'hymn', 'tone poem', 'ideology',
#        'carol', 'technique', 'lobit', 'nationalism', 'aleatory', 'Islamic',
#        'parody', 'lyrics', 'composition', 'children's music'],
#       dtype='object')

# %%
album_df.head()
# Out:
#                               Album          Artist  \
# 0                       OK Computer       Radiohead
# 1                Wish You Were Here      Pink Floyd
# 2  In the Court of the Crimson King    King Crimson
# 3               To Pimp a Butterfly  Kendrick Lamar
# 4                             Kid A       Radiohead
#
#                                             Genres  \
# 0                       Alternative Rock, Art Rock
# 1                       Progressive Rock, Art Rock
# 2                       Progressive Rock, Art Rock
# 3  Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
# 4          Art Rock, Experimental Rock, Electronic
#
#                                     Secondary_Genres  \
# 0
# 1                       Space Rock, Psychedelic Rock
# 2  Symphonic Prog, Jazz-Rock, Free Improvisation,...
# 3  Political Hip Hop, Neo-Soul, Funk, Poetry, Exp...
# 4                           Ambient, Electronic, IDM
#
#                                    Album_Descriptors
# 0  melancholic, anxious, futuristic, male vocals,...
# 1  melancholic, atmospheric, progressive, male vo...
# 2  fantasy, epic, progressive, complex, philosoph...
# 3  political, conscious, poetic, protest, concept...
# 4  cold, melancholic, futuristic, anxious, atmosp...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 3),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(album_df['Album_Genres_Descriptors'])

# %%
tfidf_matrix.shape
# Out:
# (4739, 48539)

# %%
# Cosine similarity
from sklearn.metrics.pairwise import linear_kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)


Album = album_df['Album']
# finding indices of every title
indices = pd.Series(album_df.index, index=Album)

# %%
album_df.columns
# Out:
# Index(['Album', 'Artist', 'Album_Genres_Descriptors'], dtype='object')

# %%
def get_recommendations(df, column, value, value_list, limit=1):

    # Turning value_list from a list to a string
    values = ', '.join([str(elem) for elem in value_list])
    
    # Adding a new row to the end of the Dataframe
    df = df.append({'Album':value, 'Artist':value, 'Album_Genres_Descriptors':values}, ignore_index = True)

    # Vectorizing the Album_Genres_Descriptors column
    tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 3),min_df=0, stop_words='english')
    tfidf_matrix = tf.fit_transform(df['Album_Genres_Descriptors'])
    
    cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

    indices = pd.Series(df.index, index=df[column]).drop_duplicates()

    # Get the index for the target value
    target_index = indices[value]

    # Get the cosine similarity scores for the target value
    cosine_similarity_scores = list(enumerate(cosine_similarities[target_index]))

    # Sort the cosine similarities in order of closest similarity
    cosine_similarity_scores = sorted(cosine_similarity_scores, key=lambda x: x[1], reverse=True)

    # Return tuple of the requested closest scores excluding the target item and index
    cosine_similarity_scores = cosine_similarity_scores[1:limit+1]

    # Extract the tuple values
    index = (x[0] for x in cosine_similarity_scores)
    scores = (x[1] for x in cosine_similarity_scores)

    # Get the indices for the closest items
    recommendation_indices = [i[0] for i in cosine_similarity_scores]

    # Get the actutal recommendations
    recommendations = df[column].iloc[recommendation_indices]

    # Return a dataframe
    df = pd.DataFrame(list(zip(index, recommendations, scores)), 
                      columns=['index','Album', 'Scores'])

    return df

# %%
recommendations = get_recommendations(album_df,
                                      'Album',
                                      'new-album',
                                      ['Thrash Metal', 'Acoustic Rock', 'energetic', 'male vocals', 'Alternative Rock', 'Art Rock', 'melancholic'])

recommendations.head()
# Out:
#    index                        Album    Artist
# 0   3103         Live at the Fillmore  0.711470
# 1   3900  O monstro precisa de amigos  0.215864
# 2   3921  O monstro precisa de amigos  0.215864
# 3   4472                     Innuendo  0.213631
# 4      0                  OK Computer  0.210782

# %%
print(album_df.loc[1640])
# Out:
# Album                                                              Plays Live
# Artist                                                          Peter Gabriel
# Album_Genres_Descriptors    Art Rock, Progressive Rock, Pop Rock, male vocals
# Name: 1640, dtype: object
